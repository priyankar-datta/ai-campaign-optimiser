# %% [markdown]
# # Train CTR model on synthetic data
# This notebook runs the data generator, trains XGBoost, and inspects SHAP values.

# %%
from pathlib import Path
import sys
sys.path.append('..')
print('Run data/generate_synthetic_data.py and train/train_xgb.py from the repo root')
